# %%
import pandas as pd

# %%
df = pd.read_csv('dga1.txt',sep=r'\t',header=None)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#           0                                 1                    2  \
# 0  gameover    igmw1w1wudxenelxbro1c6dfep.org  2018-01-02 00:00:00
# 1  gameover  1aa3ahh1nicfif1b4b12c161p1ip.com  2018-01-02 00:00:00
# 2  gameover     1s4hot0fvw8zpht7xyp9ze5we.biz  2018-01-02 00:00:00
# 3  gameover     wq4j8qm8dbj7tki0a21305cke.com  2018-01-02 00:00:00
# 4  gameover    1iytf25dr4p4l6a4cbh12hgqhn.com  2018-01-02 00:00:00
#
#                      3
# 0  2018-01-02 23:59:59
# 1  2018-01-02 23:59:59
# 2  2018-01-02 23:59:59
# 3  2018-01-02 23:59:59
# 4  2018-01-02 23:59:59

# %%
df.columns = ['type','domains','time1','time2']

# %%
df.head()
# Out:
#        type                           domains                time1  \
# 0  gameover    igmw1w1wudxenelxbro1c6dfep.org  2018-01-02 00:00:00
# 1  gameover  1aa3ahh1nicfif1b4b12c161p1ip.com  2018-01-02 00:00:00
# 2  gameover     1s4hot0fvw8zpht7xyp9ze5we.biz  2018-01-02 00:00:00
# 3  gameover     wq4j8qm8dbj7tki0a21305cke.com  2018-01-02 00:00:00
# 4  gameover    1iytf25dr4p4l6a4cbh12hgqhn.com  2018-01-02 00:00:00
#
#                  time2
# 0  2018-01-02 23:59:59
# 1  2018-01-02 23:59:59
# 2  2018-01-02 23:59:59
# 3  2018-01-02 23:59:59
# 4  2018-01-02 23:59:59

# %%
df.shape[0]
# Out:
# 1092529

# %%
df['type'].unique()
# Out:
# array(['gameover', 'locky', 'nymaim', 'symmi', 'conficker',
#        'pykspa_v2_real', 'pykspa_v2_fake', 'bamital', 'madmax', 'qadars',
#        'necurs', 'cryptolocker', 'proslikefan', 'ranbyus', 'murofet',
#        'suppobox', 'mirai', 'vidro', 'tofsee', 'dyre', 'chinad', 'virut',
#        'emotet', 'matsnu', 'blackhole', 'padcrypt', 'xshellghost',
#        'ccleaner', 'fobber_v1', 'dircrypt', 'tinba', 'ramnit', 'banjori',
#        'simda', 'fobber_v2', 'tempedreve', 'vawtrak', 'rovnix', 'gspy',
#        'pykspa_v1', 'shifu'], dtype=object)

# %%
a = {}

# %%
for t in df['type']:
    if t in a:
        a[t]+=1
    else:
        a[t]=1

# %%
a
# Out:
# {'bamital': 104,
#  'banjori': 452369,
#  'blackhole': 2,
#  'ccleaner': 1,
#  'chinad': 1000,
#  'conficker': 461,
#  'cryptolocker': 1000,
#  'dircrypt': 470,
#  'dyre': 1000,
#  'emotet': 223295,
#  'fobber_v1': 298,
#  'fobber_v2': 298,
#  'gameover': 12000,
#  'gspy': 100,
#  'locky': 1112,
#  'madmax': 1,
#  'matsnu': 884,
#  'mirai': 2,
#  'murofet': 5319,
#  'necurs': 8192,
#  'nymaim': 404,
#  'padcrypt': 168,
#  'proslikefan': 100,
#  'pykspa_v1': 44702,
#  'pykspa_v2_fake': 799,
#  'pykspa_v2_real': 199,
#  'qadars': 1800,
#  'ramnit': 15921,
#  'ranbyus': 4960,
#  'rovnix': 179996,
#  'shifu': 2553,
#  'simda': 24271,
#  'suppobox': 2383,
#  'symmi': 64,
#  'tempedreve': 204,
#  'tinba': 95739,
#  'tofsee': 20,
#  'vawtrak': 298,
#  'vidro': 100,
#  'virut': 9939,
#  'xshellghost': 1}

# %%
df[:1]
# Out:
#        type                         domains                time1  \
# 0  gameover  igmw1w1wudxenelxbro1c6dfep.org  2018-01-02 00:00:00
#
#                  time2
# 0  2018-01-02 23:59:59

# %%
a = df[10:11]['domains']

# %%
list(a)[0]
# Out:
# 'tp2k42ux816fi4bn2c1p2kwl.biz'

# %%
i = 0

# %%
a = df[10:11]['type']

# %%
list(a)[0]
# Out:
# 'gameover'

# %%
for i in range(df.shape[0]):
    line = df[i:i+1]
    if  b.has_key(list(line['type'])[0]):
        b[list(line['type'])[0]].append(list(line['domains'])[0])
    else:
        b[list(line['type'])[0]] = []
        b[list(line['type'])[0]].append(list(line['domains'])[0])

# %%
b
# Out:
# {'bamital': ['5f3ca1d019f3a8b18e7f7f82a8dbc0eb.co.cc',
#   'db38c6252db108ee37a39cfa3f730d3c.co.cc',
#   '29502039980331f5454004a99718a376.cz.cc',
#   'b380b3bb00821b21da3ac33ff60dfb80.org',
#   '92948e7bf4e4eafc8d62fd4f76337492.cz.cc',
#   '8a3207953087dc6b1b9e97d9e582bc89.org',
#   '5ab10149596974fa3c6cab9f6dca9dcb.co.cc',
#   'd718d3cc513fa636d175c2fd7d7312a7.info',
#   'd24be015fd21c722c2e5b707bba9b53a.info',
#   'd24be015fd21c722c2e5b707bba9b53a.co.cc',
#   'd24be015fd21c722c2e5b707bba9b53a.org',
#   '95eac2ea7e42f84726241c016ec86b42.info',
#   '622ed1b1ad91898ea7f046e1b9b404a3.info',
#   'beb908b9bcfc9fb978b4c3858a1e7a9a.info',
#   '802bf14bb68c056295f3645152a8d5aa.org',
#   'beb908b9bcfc9fb978b4c3858a1e7a9a.co.cc',
#   '062e29fc7f4f788d28475f3214c2eceb.co.cc',
#   'beb908b9bcfc9fb978b4c3858a1e7a9a.org',
#   '551704d97370328789c6e9bd0510741d.cz.cc',
#   '802bf14bb68c056295f3645152a8d5aa.cz.cc',
#   'beb908b9bcfc9fb978b4c3858a1e7a9a.cz.cc',
# ...

# %%
len(b['banjori'])
# Out:
# 452370

# %%
suffix = {}

# %%
long_short = {}

# %%
number_radio = {}

# %%
list1 = []

# %%
for d in b:
    for do in d:
        pre_do = do.split('.')[0]
        suff_do = do.partition('.')[-1]

# %%
if  bbb.has_key('a'):
    print 1
# Out:
# 1

# %%
aaaa = 'www.baidu.com'

# %%
aaaa.partition('.')
# Out:
# ('www', '.', 'baidu.com')

# %%
min(1,4,6,5)
# Out:
# 1

# %%
aaaa = ()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-061f51051b34> in <module>()
# ----> 1 aaaa.aaaa
#
# AttributeError: 'tuple' object has no attribute 'aaaa'
